# %% [markdown]
# # Regression Exercise

# %% [markdown]
# In this exercise, we willl be applying the knowledge we have thus far to build a regression model

# %% [markdown]
# We willl be using the folowing medical cost personal dataset for predicting  individuals medical costs billed by health insurance
#
# Link: https://www.kaggle.com/datasets/mirichoi0218/insurance

# %% [markdown]
# **First start by reading the dataset into a dataframe**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/content/drive/MyDrive/Datasets/Advertising.csv")
X = df.drop('sales',axis=1)
y = df['sales']

# %% [markdown]
# Display the first 5 rows of the dataframe

# %%
df.head()

# %% [markdown]
# **Based on the Data engineering knowedge perfom any required data encoding/cleaning**

# %% [markdown]
# After cleaaning, split the the  dataframe into X and y representing features and outputs

# %% [markdown]
# Spit the X and y into train and test with the ratio 80% to  20%

# %% [markdown]
# We will be using a pipeline to convert our features into higher degrees, scaing the features then fitting a ElasticNet model
#
# Start by defining our Polynomial converter after import, for simplicity name it 'conv'

# %% [markdown]
# Define the StandardScaler after importing and name it 'scaler'

# %% [markdown]
# Define the ElasticNet model after importing and name it 'model'

# %% [markdown]
# Define the operations done by the pipeline in order using a list of ordered pairs
#
# Define the pipeling after importing giving it the opearions and naming it 'pipe'

# %% [markdown]
# We will be finding the best degree  as well as modell parameters using a GridSearch
#
# Define a parameter grid specifying a ist for the degree of the poynomial convertor, a list for the l1_ratio for the model and a list for alpha for the model as well

# %% [markdown]
# Define a grid search after importing giving it the pipeline, the parameter grid and a proper scoring monitoring and cv value

# %% [markdown]
# Fit the training data using the grid search to find the best parameters

# %% [markdown]
# Evauate the model using accuracy, mean square error and mean absolute error

# %% [markdown]
# What about trying a different model, would it give the same hyperparaters? Would it give better results? Try the same steps but a different model such as LinearRegression or Ridge
